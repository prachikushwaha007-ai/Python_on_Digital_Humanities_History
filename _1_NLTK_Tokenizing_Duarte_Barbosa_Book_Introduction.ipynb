# %% [markdown]
# <a href="https://colab.research.google.com/github/prachikushwaha007-ai/Python_on_Digital_Humanities_History/blob/main/_1_NLTK_Tokenizing_Duarte_Barbosa_Book_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk

# %%
# Tokenization is a form of grouping.
# Tokenization can be done as word tokenizers & sentence tokenizers.
# lexicon amd corporas--
# corpora- body of text. eg; medical journals.
# lexicon- is like a dictionary; words and means.

# %%
# import word and sent Tokenizers.

from nltk.tokenize import sent_tokenize, word_tokenize

# %%
# Secure code structure using try and except method from being crashed.

try:
    tokens = word_tokenize("This is a test sentence.")
except LookupError:
    nltk.download('punkt_tab')
    tokens = word_tokenize("This is a test sentence.")

# %%
# file path of Duarte Barbosa's book Introduction

text = '/content/drive/MyDrive/INTRODUCTION.txt.txt'

# %%
# Open Text File.

with open('/content/drive/MyDrive/INTRODUCTION.txt.txt') as f :
     text = f.read()

print(text)
# Out:
# ﻿INTRODUCTION.
#
#
# HE author of this book was a Portuguese official named Duarte Barbosa, who, as will be shown below, was in the service of the Portuguese Government in India from about 1500 till about 1516 or 1517. His work was long known only through the Italian version of it included by Ramusio in his great collection of voyages entitled Navigationi e Viaggi, first published at Venice in 1563. A Portuguese MS. was found at Lisbon in the early part of the nineteenth century, of which an account is given in the introduction of the Portuguese editors to their edition published in 1813, and manuscripts of a Spanish version exist at Barcelona and Munich, from the former of which the first English translation, that by Lord Stanley, issued by the Hakluyt Society in 1865, was made.
#
#
# The present version is an entirely new translation from the Portuguese text of 1813.
#
#
# ...

# %%
# Tokenize by Sentences using for loop.

print(sent_tokenize(text))

for i in sent_tokenize(text):
    print(i)

len(sent_tokenize(text))
# Out:
# ['\ufeffINTRODUCTION.', 'HE author of this book was a Portuguese official named Duarte Barbosa, who, as will be shown below, was in the service of the Portuguese Government in India from about 1500 till about 1516 or 1517.', 'His work was long known only through the Italian version of it included by Ramusio in his great collection of voyages entitled Navigationi e Viaggi, first published at Venice in 1563.', 'A Portuguese MS. was found at Lisbon in the early part of the nineteenth century, of which an account is given in the introduction of the Portuguese editors to their edition published in 1813, and manuscripts of a Spanish version exist at Barcelona and Munich, from the former of which the first English translation, that by Lord Stanley, issued by the Hakluyt Society in 1865, was made.', 'The present version is an entirely new translation from the Portuguese text of 1813.', "Before considering the book and its value as one of the earliest records made by the Portuguese within a f
# ...

# %%
# Tokenize by Word using for loop.

print(word_tokenize(text))

for i in word_tokenize(text):
    print(i)

len(word_tokenize(text))
# Out:
# ['\ufeffINTRODUCTION', '.', 'HE', 'author', 'of', 'this', 'book', 'was', 'a', 'Portuguese', 'official', 'named', 'Duarte', 'Barbosa', ',', 'who', ',', 'as', 'will', 'be', 'shown', 'below', ',', 'was', 'in', 'the', 'service', 'of', 'the', 'Portuguese', 'Government', 'in', 'India', 'from', 'about', '1500', 'till', 'about', '1516', 'or', '1517', '.', 'His', 'work', 'was', 'long', 'known', 'only', 'through', 'the', 'Italian', 'version', 'of', 'it', 'included', 'by', 'Ramusio', 'in', 'his', 'great', 'collection', 'of', 'voyages', 'entitled', 'Navigationi', 'e', 'Viaggi', ',', 'first', 'published', 'at', 'Venice', 'in', '1563', '.', 'A', 'Portuguese', 'MS.', 'was', 'found', 'at', 'Lisbon', 'in', 'the', 'early', 'part', 'of', 'the', 'nineteenth', 'century', ',', 'of', 'which', 'an', 'account', 'is', 'given', 'in', 'the', 'introduction', 'of', 'the', 'Portuguese', 'editors', 'to', 'their', 'edition', 'published', 'in', '1813', ',', 'and', 'manuscripts', 'of', 'a', 'Spanish', 'version', 'exis
# ...

# %%
# import stopwords.

from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# stopwords is a set of english stopwords that have already been predefined by NLTK.

stopwords = set(stopwords.words('english'))
print(stopwords)

len(stopwords)
# Out:
# {'out', 'mustn', 'his', 'himself', 'won', 'whom', 'which', 'y', 'while', "it'll", "he'll", "i'll", 'more', 'no', 'weren', 'can', 'as', 'of', 'myself', 'if', 'itself', 'but', 'd', 'that', 'with', 'will', 'couldn', "wasn't", "aren't", 're', "you're", 'an', 'should', 'o', 'such', 'for', 'doesn', 'into', "you'd", 'its', "mightn't", 'on', 'yours', 'didn', 'our', "she'll", 'only', 'hers', 'wouldn', "couldn't", 'we', 'it', "he'd", "weren't", "you'll", 'ourselves', 'don', 'has', 'from', 'about', "shouldn't", 'this', 'll', 'the', 'he', 'being', 'she', 'wasn', 'very', 'where', 'above', 'once', 'your', 'between', "won't", "didn't", "we'll", 'him', "haven't", 'theirs', 'what', "we're", "they'd", 'having', 'hadn', 'below', "hasn't", "she'd", 'shouldn', 'against', 'then', "mustn't", 'in', 'most', 'i', 'her', 'herself', "hadn't", "i'm", 'too', 'at', 'yourself', 'ma', 'they', 'during', 'been', 'haven', 'yourselves', "isn't", "doesn't", "i'd", "that'll", 'not', "he's", 'nor', 'to', "it's", 'down', 'f
# ...

# %%
words = word_tokenize(text)

# %%
# To filter the text: method one.

filtered_text = []

for w in words:
    if w not in stopwords:
       filtered_text.append(w)

print(filtered_text)

len(filtered_text)
# Out:
# ['\ufeffINTRODUCTION', '.', 'HE', 'author', 'book', 'Portuguese', 'official', 'named', 'Duarte', 'Barbosa', ',', ',', 'shown', ',', 'service', 'Portuguese', 'Government', 'India', '1500', 'till', '1516', '1517', '.', 'His', 'work', 'long', 'known', 'Italian', 'version', 'included', 'Ramusio', 'great', 'collection', 'voyages', 'entitled', 'Navigationi', 'e', 'Viaggi', ',', 'first', 'published', 'Venice', '1563', '.', 'A', 'Portuguese', 'MS.', 'found', 'Lisbon', 'early', 'part', 'nineteenth', 'century', ',', 'account', 'given', 'introduction', 'Portuguese', 'editors', 'edition', 'published', '1813', ',', 'manuscripts', 'Spanish', 'version', 'exist', 'Barcelona', 'Munich', ',', 'former', 'first', 'English', 'translation', ',', 'Lord', 'Stanley', ',', 'issued', 'Hakluyt', 'Society', '1865', ',', 'made', '.', 'The', 'present', 'version', 'entirely', 'new', 'translation', 'Portuguese', 'text', '1813', '.', 'Before', 'considering', 'book', 'value', 'one', 'earliest', 'records', 'made', 'Por
# ...

# %%
# To filter the text: method two.

filtered_text = [w for w in words if not w in stopwords]

print(filtered_text)

len(filtered_text)
# Out:
# ['\ufeffINTRODUCTION', '.', 'HE', 'author', 'book', 'Portuguese', 'official', 'named', 'Duarte', 'Barbosa', ',', ',', 'shown', ',', 'service', 'Portuguese', 'Government', 'India', '1500', 'till', '1516', '1517', '.', 'His', 'work', 'long', 'known', 'Italian', 'version', 'included', 'Ramusio', 'great', 'collection', 'voyages', 'entitled', 'Navigationi', 'e', 'Viaggi', ',', 'first', 'published', 'Venice', '1563', '.', 'A', 'Portuguese', 'MS.', 'found', 'Lisbon', 'early', 'part', 'nineteenth', 'century', ',', 'account', 'given', 'introduction', 'Portuguese', 'editors', 'edition', 'published', '1813', ',', 'manuscripts', 'Spanish', 'version', 'exist', 'Barcelona', 'Munich', ',', 'former', 'first', 'English', 'translation', ',', 'Lord', 'Stanley', ',', 'issued', 'Hakluyt', 'Society', '1865', ',', 'made', '.', 'The', 'present', 'version', 'entirely', 'new', 'translation', 'Portuguese', 'text', '1813', '.', 'Before', 'considering', 'book', 'value', 'one', 'earliest', 'records', 'made', 'Por
# ...
