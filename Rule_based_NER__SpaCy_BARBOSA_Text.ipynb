# %% [markdown]
# <a href="https://colab.research.google.com/github/prachikushwaha007-ai/Python_on_Digital_Humanities_History/blob/main/Rule_based_NER__SpaCy_BARBOSA_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
# !python -m spacy download en_core_web_lg

nlp = spacy.load("en_core_web_lg")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 1.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
with open('/content/drive/MyDrive/BARBOSA.txt', 'r') as f:
   text = f.read()
print(text)
# Out:
# ﻿THE BOOK OF DUARTE BARBOSA.
#
#
# §1. FIRSTLY, THE CAPE OF SAM SABASTIAM.
#
#
# RAVELLING along the coast after passing the Cape of Good Hope in the direction of India as far as that of Sam Sabastiam¹ there are certain fair lands with many hills and open plains wherein are numerous herds of cows in abundance, sheep and other wild cattle. The dwellers in this land are black folk; they go naked, wearing only skins, whether of deer or other wild beasts, and some of them wear French capes. And our men could never learn aught of the speech of these peoples, nor what merchandize goes into their country. They know nothing of navigation, nor do they make use of the sea, and the Moors of Arabia and Persia have never sailed to that region nor discovered it, by reason that Cape Correntes is exceeding stormy.
#
#
# § 2. THE ISLANDS WHICH THEY CALL THE GREAT HUCICAS.
#
#
# ...

# %%
# Form a document.

doc = nlp(text)

# %%
for ent in doc.ents:
   print(f'Entity: {ent.text}, Label: {ent.label_}')
# Out:
# Entity: DUARTE BARBOSA, Label: PERSON
# Entity: 1, Label: CARDINAL
# Entity: FIRSTLY, Label: ORDINAL
# Entity: SAM SABASTIAM., Label: PERSON
# Entity: India, Label: GPE
# Entity: Sam Sabastiam¹, Label: PERSON
# Entity: French, Label: NORP
# Entity: Arabia, Label: GPE
# Entity: Persia, Label: GPE
# Entity: Cape Correntes, Label: LOC
# Entity: 2, Label: CARDINAL
# Entity: Cape, Label: LOC
# Entity: Sam Sabastiam, Label: PERSON
# Entity: India, Label: GPE
# Entity: Hucicas, Label: GPE
# Entity: them¹, Label: PERSON
# Entity: 3, Label: CARDINAL
# Entity: Hucicas, Label: GPE
# Entity: Çofala, Label: GPE
# Entity: the King of Portugal, Label: GPE
# Entity: seventeen or eighteen, Label: DATE
# Entity: Çofalas, Label: GPE
# Entity: 4, Label: CARDINAL
# Entity: ÇOFALA, Label: ORG
# Entity: India, Label: GPE
# Entity: Hucicas, Label: GPE
# Entity: twenty or, Label: CARDINAL
# Entity: thirty, Label: CARDINAL
# Entity: Cofala, Label: PERSON
# Entity: Arabic, Label: LANGUAGE
# ...

# %%
nlp2 = spacy.load("en_core_web_lg")

# %%
from spacy.pipeline import EntityRuler

# %%
ruler = nlp2.add_pipe('entity_ruler', config={'phrase_matcher_attr': 'LOWER'}, before='ner')

# %%
patterns = [
       {'label': 'GPE', 'pattern': 'Moçambique'},
       {'label': 'GPE', 'pattern': 'Benametapa'},
       {'label': 'GPE', 'pattern': 'Benametapal'},
       {'label': 'GPE', 'pattern': 'Melynde'},
       {'label': 'GPE', 'pattern': 'Mombaça'},
       {'label': 'GPE', 'pattern': 'Melinde'},
       {'label': 'GPE', 'pattern': 'Quiloa'},
       {'label': 'GPE', 'pattern': 'Cuama'},
       {'label': 'GPE', 'pattern': 'Angoya'},
       {'label': 'GPE', 'pattern': 'pemba'},
       {'label': 'GPE', 'pattern': 'zinzibar'},
       {'label': 'GPE', 'pattern': 'Cofala'},
       {'label': 'GPE', 'pattern': 'Zimbaoche'},
       {'label': 'GPE', 'pattern': 'Cambay'},
       {'label': 'GPE', 'pattern': 'Cambaya'},
       {'label': 'GPE', 'pattern': 'the Isles of Zinzibar'},
       {'label': 'LOC', 'pattern': 'SAM SABASTIAM'},
       {'label': 'LOC', 'pattern': 'Sam Sabastiam¹'},
       {'label': 'LOC', 'pattern': 'Cape Correntes¹1'},
       {'label': 'VEHICLE', 'pattern': 'Zambucos'},
       {'label': 'VEHICLE', 'pattern': 'Zambuco'},
       {'label': 'VEHICLE', 'pattern': 'almadias'},
       {'label': 'WEAPON', 'pattern': 'assegais¹'},
       {'label': 'WEAPON', 'pattern': 'assegai'},
       {'label': 'NORP', 'pattern': 'moors'},
       {'label': 'NORP', 'pattern': 'Cafres'},
       {'label': 'PERSON', 'pattern': 'the King of Portugal'},
       {'label': 'WORK_OF_ART', 'pattern': 'Alcoran'},


]

# %%
ruler.add_patterns(patterns)

# %%
doc = nlp2(text)

# %%
for ent in doc.ents:
   print(f'Entity: {ent.text}, Label: {ent.label_}')
# Out:
# Entity: DUARTE BARBOSA, Label: PERSON
# Entity: 1, Label: CARDINAL
# Entity: FIRSTLY, Label: ORDINAL
# Entity: SAM SABASTIAM, Label: LOC
# Entity: India, Label: GPE
# Entity: Sam Sabastiam¹, Label: LOC
# Entity: French, Label: NORP
# Entity: Moors, Label: NORP
# Entity: Arabia, Label: GPE
# Entity: Persia, Label: GPE
# Entity: Cape Correntes, Label: LOC
# Entity: 2, Label: CARDINAL
# Entity: Cape, Label: LOC
# Entity: Sam Sabastiam, Label: LOC
# Entity: India, Label: GPE
# Entity: Moors, Label: NORP
# Entity: Hucicas, Label: GPE
# Entity: Moors, Label: NORP
# Entity: them¹, Label: PERSON
# Entity: 3, Label: CARDINAL
# Entity: Hucicas, Label: GPE
# Entity: Çofala, Label: GPE
# Entity: the King of Portugal, Label: PERSON
# Entity: seventeen or eighteen, Label: DATE
# Entity: Moors, Label: NORP
# Entity: Çofalas, Label: GPE
# Entity: 4, Label: CARDINAL
# Entity: ÇOFALA, Label: ORG
# Entity: India, Label: GPE
# Entity: Hucicas, Label: GPE
# Entity: twenty or, Label: CARDINAL
# ...
